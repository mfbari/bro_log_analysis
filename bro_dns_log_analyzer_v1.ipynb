# %% [markdown]
# Import necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from bat import bro_log_reader
import pprint
pp = pprint.PrettyPrinter(indent=4)

# %%
reader = bro_log_reader.BroLogReader('data/dns.log')

# %%
for row in reader.readrows():
    pp.pprint(row)
# Out:
# Successfully monitoring data/dns.log...
# {   'AA': False,
#     'RA': True,
#     'RD': True,
#     'TC': False,
#     'TTLs': '36.000000',
#     'Z': 0,
#     'answers': '54.245.228.191',
#     'id.orig_h': '192.168.33.10',
#     'id.orig_p': 1030,
#     'id.resp_h': '4.2.2.3',
#     'id.resp_p': 53,
#     'proto': 'udp',
#     'qclass': 1,
#     'qclass_name': 'C_INTERNET',
#     'qtype': 1,
#     'qtype_name': 'A',
#     'query': 'guyspy.com',
#     'rcode': 0,
#     'rcode_name': 'NOERROR',
#     'rejected': False,
#     'trans_id': 44949,
#     'ts': datetime.datetime(2013, 9, 15, 19, 44, 27, 631940),
#     'uid': 'CZGShC2znK1sV7jdI7'}
# {   'AA': False,
#     'RA': True,
#     'RD': True,
#     'TC': False,
#     'TTLs': '1000.000000,36.000000',
#     'Z': 0,
#     'answers': 'guyspy.com,54.245.228.191',
#     'id.orig_h': '192.168.33.10',
#     'id.orig_p': 1030,
#     'id.resp_h': '4.2.2.3',
#     'id.resp_p': 53,
#     'proto': 'udp',
#     'qclass': 1,
#     'qclass_name': 'C_INTERNET',
#     'qtype': 1,
#     'qtype_name': 'A',
#     'query': 'www.guyspy.com',
#     'rcode': 0,
#     'rcode_name': 'NOERROR',
#     'rejected': False,
#     'trans_id': 50071,
#     'ts': datetime.datetime(2013, 9, 15, 19, 44, 27, 696869),
#     'uid': 'CZGShC2znK1sV7jdI7'}
# {   'AA': False,
#     'RA': True,
#     'RD': True,
#     'TC': False,
#     'TTLs': '60.000000,60.000000,60.000000,60.000000,60.000000,60.000000,60.000000,60.000000',
#     'Z': 0,
#     'answers': '54.230.86.87,54.230.86.18,54.230.87.160,54.230.85.131,54.230.85.125,205.251.203.11,54.230.86.191,54.230.87.110',
#     'id.orig_h': '192.168.33.10',
#     'id.orig_p': 1030,
#     'id.resp_h': '4.2.2.3',
#     'id.resp_p': 53,
#     'proto': 'udp',
#     'qclass': 1,
#     'qclass_name': 'C_INTERNET',
#     'qtype': 1,
#     'qtype_name': 'A',
#     'query': 'devrubn8mli40.cloudfront.net',
#     'rcode': 0,
#     'rcode_name': 'NOERROR',
#     'rejected': False,
#     'trans_id': 39062,
#     'ts': datetime.datetime(2013, 9, 15, 19, 44, 28, 60639),
#     'uid': 'CZGShC2znK1sV7jdI7'}
# {   'AA': False,
#     'RA': True,
#     'RD': True,
#     'TC': False,
#     'TTLs': '60.000000,60.000000,60.000000,60.000000,60.000000,60.000000,60.000000,60.000000',
#     'Z': 0,
#     'answers': '54.230.86.87,54.230.86.18,54.230.84.20,54.230.87.51,54.230.85.175,54.230.84.77,205.251.203.232,54.230.84.111',
#     'id.orig_h': '192.168.33.10',
#     'id.orig_p': 1030,
#     'id.resp_h': '4.2.2.3',
#     'id.resp_p': 53,
#     'proto': 'udp',
#     'qclass': 1,
#     'qclass_name': 'C_INTERNET',
#     'qtype': 1,
#     'qtype_name': 'A',
#     'query': 'd31qbv1cthcecs.cloudfront.net',
#     'rcode': 0,
#     'rcode_name': 'NOERROR',
#     'rejected': False,
#     'trans_id': 7312,
#     'ts': datetime.datetime(2013, 9, 15, 19, 44, 28, 141795),
#     'uid': 'CZGShC2znK1sV7jdI7'}
# {   'AA': False,
#     'RA': True,
#     'RD': True,
#     'TC': False,
#     'TTLs': '4993.000000,129.000000,129.000000,129.000000',
#     'Z': 0,
#     'answers': 'cdn.entrust.net.c.footprint.net,192.221.123.252,8.26.198.253,4.27.23.126',
#     'id.orig_h': '192.168.33.10',
#     'id.orig_p': 1030,
#     'id.resp_h': '4.2.2.3',
#     'id.resp_p': 53,
#     'proto': 'udp',
#     'qclass': 1,
#     'qclass_name': 'C_INTERNET',
#     'qtype': 1,
#     'qtype_name': 'A',
#     'query': 'crl.entrust.net',
#     'rcode': 0,
#     'rcode_name': 'NOERROR',
#     'rejected': False,
#     'trans_id': 41872,
#     'ts': datetime.datetime(2013, 9, 15, 19, 44, 28, 422704),
#     'uid': 'CZGShC2znK1sV7jdI7'}
# {   'AA': False,
#     'RA': True,
#     'RD': True,
#     'TC': False,
#     'TTLs': '6645.000000,18435.000000',
#     'Z': 0,
#     'answers': 'cs9.wac.edgecastcdn.net,72.21.91.29',
#     'id.orig_h': '192.168.33.10',
#     'id.orig_p': 1030,
#     'id.resp_h': '4.2.2.3',
#     'id.resp_p': 53,
#     'proto': 'udp',
#     'qclass': 1,
#     'qclass_name': 'C_INTERNET',
#     'qtype': 1,
#     'qtype_name': 'A',
#     'query': 'crl3.digicert.com',
#     'rcode': 0,
#     'rcode_name': 'NOERROR',
#     'rejected': False,
#     'trans_id': 30866,
#     'ts': datetime.datetime(2013, 9, 15, 19, 44, 28, 533679),
#     'uid': 'CZGShC2znK1sV7jdI7'}
# {   'AA': False,
#     'RA': True,
#     'RD': True,
#     'TC': False,
#     'TTLs': '60688.000000,154.000000,154.000000,154.000000,154.000000',
#     'Z': 0,
#     'answers': 'stats.l.doubleclick.net,74.125.28.156,74.125.28.155,74.125.28.157,74.125.28.154',
#     'id.orig_h': '192.168.33.10',
#     'id.orig_p': 1030,
#     'id.resp_h': '4.2.2.3',
#     'id.resp_p': 53,
#     'proto': 'udp',
#     'qclass': 1,
#     'qclass_name': 'C_INTERNET',
#     'qtype': 1,
#     'qtype_name': 'A',
#     'query': 'stats.g.doubleclick.net',
#     'rcode': 0,
#     'rcode_name': 'NOERROR',
#     'rejected': False,
#     'trans_id': 16018,
#     'ts': datetime.datetime(2013, 9, 15, 19, 44, 29, 353869),
#     'uid': 'CZGShC2znK1sV7jdI7'}
# {   'AA': False,
#     'RA': True,
#     'RD': True,
#     'TC': False,
#     'TTLs': '181.000000,0.000000,0.000000,0.000000',
#     'Z': 0,
#     'answers': 'pagead46.l.doubleclick.net,74.125.224.77,74.125.224.89,74.125.224.90',
#     'id.orig_h': '192.168.33.10',
#     'id.orig_p': 1081,
#     'id.resp_h': '4.2.2.3',
#     'id.resp_p': 53,
#     'proto': 'udp',
#     'qclass': 1,
#     'qclass_name': 'C_INTERNET',
#     'qtype': 1,
#     'qtype_name': 'A',
#     'query': 'www.googletagservices.com',
#     'rcode': 0,
#     'rcode_name': 'NOERROR',
#     'rejected': False,
#     'trans_id': 34194,
#     'ts': datetime.datetime(2013, 9, 15, 19, 44, 29, 357407),
#     'uid': 'C3FEbf1UE7vMLkkQLc'}
# {   'AA': False,
#     'RA': True,
#     'RD': True,
#     'TC': False,
#     'TTLs': '300.000000',
#     'Z': 0,
#     'answers': '108.168.224.130',
#     'id.orig_h': '192.168.33.10',
#     'id.orig_p': 1082,
#     'id.resp_h': '4.2.2.3',
#     'id.resp_p': 53,
#     'proto': 'udp',
#     'qclass': 1,
#     'qclass_name': 'C_INTERNET',
#     'qtype': 1,
#     'qtype_name': 'A',
#     'query': 'dev.visualwebsiteoptimizer.com',
#     'rcode': 0,
#     'rcode_name': 'NOERROR',
#     'rejected': False,
#     'trans_id': 413,
#     'ts': datetime.datetime(2013, 9, 15, 19, 44, 29, 359003),
#     'uid': 'CcPje84S41RSIFFHe2'}
# {   'AA': False,
#     'RA': True,
#     'RD': True,
#     'TC': False,
#     'TTLs': '43.000000,98.000000,98.000000,98.000000',
#     'Z': 0,
#     'answers': 'partnerad.l.doubleclick.net,74.125.239.26,74.125.239.13,74.125.239.25',
#     'id.orig_h': '192.168.33.10',
#     'id.orig_p': 1030,
#     'id.resp_h': '4.2.2.3',
#     'id.resp_p': 53,
#     'proto': 'udp',
#     'qclass': 1,
#     'qclass_name': 'C_INTERNET',
#     'qtype': 1,
#     'qtype_name': 'A',
#     'query': 'partner.googleadservices.com',
#     'rcode': 0,
#     'rcode_name': 'NOERROR',
#     'rejected': False,
#     'trans_id': 11164,
#     'ts': datetime.datetime(2013, 9, 15, 19, 44, 29, 505645),
#     'uid': 'CZGShC2znK1sV7jdI7'}
# {   'AA': False,
#     'RA': True,
#     'RD': True,
#     'TC': False,
#     'TTLs': '59930.000000,122.000000,122.000000,122.000000,122.000000,122.000000,122.000000,122.000000,122.000000,122.000000,122.000000,122.000000',
#     'Z': 0,
#     'answers': 'www-google-analytics.l.google.com,74.125.224.104,74.125.224.98,74.125.224.102,74.125.224.96,74.125.224.97,74.125.224.103,74.125.224.110,74.125.224.101,74.125.224.99,74.125.224.105,74.125.224.100',
#     'id.orig_h': '192.168.33.10',
#     'id.orig_p': 1030,
#     'id.resp_h': '4.2.2.3',
#     'id.resp_p': 53,
#     'proto': 'udp',
#     'qclass': 1,
#     'qclass_name': 'C_INTERNET',
#     'qtype': 1,
#     'qtype_name': 'A',
#     'query': 'www.google-analytics.com',
#     'rcode': 0,
#     'rcode_name': 'NOERROR',
#     'rejected': False,
#     'trans_id': 50591,
#     'ts': datetime.datetime(2013, 9, 15, 19, 44, 29, 529190),
#     'uid': 'CZGShC2znK1sV7jdI7'}
# {   'AA': False,
#     'RA': True,
#     'RD': True,
#     'TC': False,
#     'TTLs': '22.000000,22.000000,22.000000,22.000000,22.000000,22.000000,22.000000,22.000000',
#     'Z': 0,
#     'answers': '205.251.203.117,54.230.87.209,54.230.87.115,54.230.86.224,54.230.85.180,54.230.87.51,205.251.203.125,205.251.203.11',
#     'id.orig_h': '192.168.33.10',
#     'id.orig_p': 1030,
#     'id.resp_h': '4.2.2.3',
#     'id.resp_p': 53,
#     'proto': 'udp',
#     'qclass': 1,
#     'qclass_name': 'C_INTERNET',
#     'qtype': 1,
#     'qtype_name': 'A',
#     'query': 'd5nxst8fruw4z.cloudfront.net',
#     'rcode': 0,
#     'rcode_name': 'NOERROR',
#     'rejected': False,
#     'trans_id': 41887,
#     'ts': datetime.datetime(2013, 9, 15, 19, 44, 29, 803241),
#     'uid': 'CZGShC2znK1sV7jdI7'}
# {   'AA': False,
#     'RA': True,
#     'RD': True,
#     'TC': False,
#     'TTLs': '60014.000000,97.000000,97.000000,97.000000',
#     'Z': 0,
#     'answers': 'partnerad.l.doubleclick.net,74.125.239.26,74.125.239.13,74.125.239.25',
#     'id.orig_h': '192.168.33.10',
#     'id.orig_p': 1030,
#     'id.resp_h': '4.2.2.3',
#     'id.resp_p': 53,
#     'proto': 'udp',
#     'qclass': 1,
#     'qclass_name': 'C_INTERNET',
#     'qtype': 1,
#     'qtype_name': 'A',
#     'query': 'pubads.g.doubleclick.net',
#     'rcode': 0,
#     'rcode_name': 'NOERROR',
#     'rejected': False,
#     'trans_id': 3225,
#     'ts': datetime.datetime(2013, 9, 15, 19, 44, 30, 57348),
#     'uid': 'CZGShC2znK1sV7jdI7'}
# {   'AA': False,
#     'RA': True,
#     'RD': True,
#     'TC': False,
#     'TTLs': '3303.000000,617.000000,8555.000000,30.000000,30.000000,30.000000,30.000000,30.000000,30.000000,30.000000,30.000000',
#     'Z': 0,
#     'answers': 'ib.adnxs.com,g.geogslb.com,ib.anycast.adnxs.com,68.67.151.135,68.67.151.104,68.67.128.27,68.67.151.162,68.67.151.164,68.67.151.166,68.67.151.51,68.67.151.230',
#     'id.orig_h': '192.168.33.10',
#     'id.orig_p': 1081,
#     'id.resp_h': '4.2.2.3',
#     'id.resp_p': 53,
#     'proto': 'udp',
#     'qclass': 1,
#     'qclass_name': 'C_INTERNET',
#     'qtype': 1,
#     'qtype_name': 'A',
#     'query': 'tag.gayadnetwork.com',
#     'rcode': 0,
#     'rcode_name': 'NOERROR',
#     'rejected': False,
#     'trans_id': 13976,
#     'ts': datetime.datetime(2013, 9, 15, 19, 44, 31, 323027),
#     'uid': 'C3FEbf1UE7vMLkkQLc'}
# {   'AA': False,
#     'RA': True,
#     'RD': True,
#     'TC': False,
#     'TTLs': '275.000000,57.000000,57.000000,57.000000,57.000000,57.000000,57.000000,57.000000,57.000000',
#     'Z': 0,
#     'answers': 'devrubn8mli40.cloudfront.net,54.230.86.87,54.230.86.18,54.230.87.160,54.230.85.131,54.230.85.125,205.251.203.11,54.230.86.191,54.230.87.110',
#     'id.orig_h': '192.168.33.10',
#     'id.orig_p': 1081,
#     'id.resp_h': '4.2.2.3',
#     'id.resp_p': 53,
#     'proto': 'udp',
#     'qclass': 1,
#     'qclass_name': 'C_INTERNET',
#     'qtype': 1,
#     'qtype_name': 'A',
#     'query': 'cdn.guyspy.com',
#     'rcode': 0,
#     'rcode_name': 'NOERROR',
#     'rejected': False,
#     'trans_id': 19099,
#     'ts': datetime.datetime(2013, 9, 15, 19, 44, 31, 340529),
#     'uid': 'C3FEbf1UE7vMLkkQLc'}
# {   'AA': False,
#     'RA': True,
#     'RD': True,
#     'TC': False,
#     'TTLs': '42.000000,300.000000,300.000000,300.000000',
#     'Z': 0,
#     'answers': 'pagead46.l.doubleclick.net,74.125.224.185,74.125.224.173,74.125.224.186',
#     'id.orig_h': '192.168.33.10',
#     'id.orig_p': 1030,
#     'id.resp_h': '4.2.2.3',
#     'id.resp_p': 53,
#     'proto': 'udp',
#     'qclass': 1,
#     'qclass_name': 'C_INTERNET',
#     'qtype': 1,
#     'qtype_name': 'A',
#     'query': 'pagead2.googlesyndication.com',
#     'rcode': 0,
#     'rcode_name': 'NOERROR',
#     'rejected': False,
#     'trans_id': 33689,
#     'ts': datetime.datetime(2013, 9, 15, 19, 44, 31, 300446),
#     'uid': 'CZGShC2znK1sV7jdI7'}
# {   'AA': False,
#     'RA': True,
#     'RD': True,
#     'TC': False,
#     'TTLs': '617.000000,8555.000000,30.000000,30.000000,30.000000,30.000000,30.000000,30.000000,30.000000,30.000000',
#     'Z': 0,
#     'answers': 'g.geogslb.com,ib.anycast.adnxs.com,68.67.151.135,68.67.151.104,68.67.128.27,68.67.151.162,68.67.151.164,68.67.151.166,68.67.151.51,68.67.151.230',
#     'id.orig_h': '192.168.33.10',
#     'id.orig_p': 1081,
#     'id.resp_h': '4.2.2.3',
#     'id.resp_p': 53,
#     'proto': 'udp',
#     'qclass': 1,
#     'qclass_name': 'C_INTERNET',
#     'qtype': 1,
#     'qtype_name': 'A',
#     'query': 'ib.adnxs.com',
#     'rcode': 0,
#     'rcode_name': 'NOERROR',
#     'rejected': False,
#     'trans_id': 20890,
#     'ts': datetime.datetime(2013, 9, 15, 19, 44, 31, 445827),
#     'uid': 'C3FEbf1UE7vMLkkQLc'}
# {   'AA': False,
#     'RA': True,
#     'RD': True,
#     'TC': False,
#     'TTLs': '213.000000,300.000000,300.000000,300.000000',
#     'Z': 0,
#     'answers': 'pagead46.l.doubleclick.net,74.125.224.185,74.125.224.173,74.125.224.186',
#     'id.orig_h': '192.168.33.10',
#     'id.orig_p': 1030,
#     'id.resp_h': '4.2.2.3',
#     'id.resp_p': 53,
#     'proto': 'udp',
#     'qclass': 1,
#     'qclass_name': 'C_INTERNET',
#     'qtype': 1,
#     'qtype_name': 'A',
#     'query': 'googleads.g.doubleclick.net',
#     'rcode': 0,
#     'rcode_name': 'NOERROR',
#     'rejected': False,
#     'trans_id': 42394,
#     'ts': datetime.datetime(2013, 9, 15, 19, 44, 31, 448852),
#     'uid': 'CZGShC2znK1sV7jdI7'}
# {   'AA': False,
#     'RA': True,
#     'RD': True,
#     'TC': False,
#     'TTLs': '786.000000,29.000000',
#     'Z': 0,
#     'answers': 'star.c10r.facebook.com,173.252.112.23',
#     'id.orig_h': '192.168.33.10',
#     'id.orig_p': 1081,
#     'id.resp_h': '4.2.2.3',
#     'id.resp_p': 53,
#     'proto': 'udp',
#     'qclass': 1,
#     'qclass_name': 'C_INTERNET',
#     'qtype': 1,
#     'qtype_name': 'A',
#     'query': 'www.facebook.com',
#     'rcode': 0,
#     'rcode_name': 'NOERROR',
#     'rejected': False,
#     'trans_id': 10116,
#     'ts': datetime.datetime(2013, 9, 15, 19, 44, 31, 589160),
#     'uid': 'C3FEbf1UE7vMLkkQLc'}
# {   'AA': False,
#     'RA': True,
#     'RD': True,
#     'TC': False,
#     'TTLs': '2.000000,2.000000,2.000000,2.000000,2.000000,2.000000,2.000000,2.000000',
#     'Z': 0,
#     'answers': '68.67.151.155,68.67.151.41,68.67.151.24,68.67.151.164,68.67.151.39,68.67.128.36,68.67.128.38,68.67.151.153',
#     'id.orig_h': '192.168.33.10',
#     'id.orig_p': 1081,
#     'id.resp_h': '4.2.2.3',
#     'id.resp_p': 53,
#     'proto': 'udp',
#     'qclass': 1,
#     'qclass_name': 'C_INTERNET',
#     'qtype': 1,
#     'qtype_name': 'A',
#     'query': 'lax1.ib.adnxs.com',
#     'rcode': 0,
#     'rcode_name': 'NOERROR',
#     'rejected': False,
#     'trans_id': 27783,
#     'ts': datetime.datetime(2013, 9, 15, 19, 44, 31, 864061),
#     'uid': 'C3FEbf1UE7vMLkkQLc'}
# {   'AA': False,
#     'RA': True,
#     'RD': True,
#     'TC': False,
#     'TTLs': '14400.000000',
#     'Z': 0,
#     'answers': '208.113.199.38',
#     'id.orig_h': '192.168.33.10',
#     'id.orig_p': 1030,
#     'id.resp_h': '4.2.2.3',
#     'id.resp_p': 53,
#     'proto': 'udp',
#     'qclass': 1,
#     'qclass_name': 'C_INTERNET',
#     'qtype': 1,
#     'qtype_name': 'A',
#     'query': 'www.gayadnetwork.com',
#     'rcode': 0,
#     'rcode_name': 'NOERROR',
#     'rejected': False,
#     'trans_id': 46727,
#     'ts': datetime.datetime(2013, 9, 15, 19, 44, 31, 864814),
#     'uid': 'CZGShC2znK1sV7jdI7'}
# {   'AA': False,
#     'RA': True,
#     'RD': True,
#     'TC': False,
#     'TTLs': '10982.000000,300.000000,60.000000,60.000000',
#     'Z': 0,
#     'answers': 'usw.insight.adsrvr.org,ttd-uswest-insight-adsrvr-org-875663112.us-west-1.elb.amazonaws.com,54.241.252.199,54.241.19.89',
#     'id.orig_h': '192.168.33.10',
#     'id.orig_p': 1081,
#     'id.resp_h': '4.2.2.3',
#     'id.resp_p': 53,
#     'proto': 'udp',
#     'qclass': 1,
#     'qclass_name': 'C_INTERNET',
#     'qtype': 1,
#     'qtype_name': 'A',
#     'query': 'insight.adsrvr.org',
#     'rcode': 0,
#     'rcode_name': 'NOERROR',
#     'rejected': False,
#     'trans_id': 7553,
#     'ts': datetime.datetime(2013, 9, 15, 19, 44, 32, 19023),
#     'uid': 'C3FEbf1UE7vMLkkQLc'}
# {   'AA': False,
#     'RA': True,
#     'RD': True,
#     'TC': False,
#     'TTLs': '219.000000,50.000000,50.000000,50.000000',
#     'Z': 0,
#     'answers': 'segments.adap.tv,74.217.78.146,74.217.78.158,74.217.78.184',
#     'id.orig_h': '192.168.33.10',
#     'id.orig_p': 1081,
#     'id.resp_h': '4.2.2.3',
#     'id.resp_p': 53,
#     'proto': 'udp',
#     'qclass': 1,
#     'qclass_name': 'C_INTERNET',
#     'qtype': 1,
#     'qtype_name': 'A',
#     'query': 'sync.adap.tv',
#     'rcode': 0,
#     'rcode_name': 'NOERROR',
#     'rejected': False,
#     'trans_id': 45952,
#     'ts': datetime.datetime(2013, 9, 15, 19, 44, 32, 97239),
#     'uid': 'C3FEbf1UE7vMLkkQLc'}
# {   'AA': False,
#     'RA': True,
#     'RD': True,
#     'TC': False,
#     'TTLs': '59941.000000,238.000000,238.000000',
#     'Z': 0,
#     'answers': 'dart.l.doubleclick.net,74.125.224.124,74.125.224.123',
#     'id.orig_h': '192.168.33.10',
#     'id.orig_p': 1081,
#     'id.resp_h': '4.2.2.3',
#     'id.resp_p': 53,
#     'proto': 'udp',
#     'qclass': 1,
#     'qclass_name': 'C_INTERNET',
#     'qtype': 1,
#     'qtype_name': 'A',
#     'query': 'ad.doubleclick.net',
#     'rcode': 0,
#     'rcode_name': 'NOERROR',
#     'rejected': False,
#     'trans_id': 52867,
#     'ts': datetime.datetime(2013, 9, 15, 19, 44, 32, 329671),
#     'uid': 'C3FEbf1UE7vMLkkQLc'}
# {   'AA': False,
#     'RA': True,
#     'RD': True,
#     'TC': False,
#     'TTLs': '298.000000,298.000000,298.000000,298.000000,298.000000',
#     'Z': 0,
#     'answers': '74.125.224.80,74.125.224.81,74.125.224.83,74.125.224.82,74.125.224.84',
#     'id.orig_h': '192.168.33.10',
#     'id.orig_p': 1081,
#     'id.resp_h': '4.2.2.3',
#     'id.resp_p': 53,
#     'proto': 'udp',
#     'qclass': 1,
#     'qclass_name': 'C_INTERNET',
#     'qtype': 1,
#     'qtype_name': 'A',
#     'query': 'www.google.com',
#     'rcode': 0,
#     'rcode_name': 'NOERROR',
#     'rejected': False,
#     'trans_id': 2434,
#     'ts': datetime.datetime(2013, 9, 15, 19, 44, 32, 356807),
#     'uid': 'C3FEbf1UE7vMLkkQLc'}
# {   'AA': False,
#     'RA': True,
#     'RD': True,
#     'TC': False,
#     'TTLs': '271.000000,7409.000000,13.000000',
#     'Z': 0,
#     'answers': 'crl.ws.symantec.com.edgekey.net,e6845.ce.akamaiedge.net,23.5.5.163',
#     'id.orig_h': '192.168.33.10',
#     'id.orig_p': 1081,
#     'id.resp_h': '4.2.2.3',
#     'id.resp_p': 53,
#     'proto': 'udp',
#     'qclass': 1,
#     'qclass_name': 'C_INTERNET',
#     'qtype': 1,
#     'qtype_name': 'A',
#     'query': 'crl.geotrust.com',
#     'rcode': 0,
#     'rcode_name': 'NOERROR',
#     'rejected': False,
#     'trans_id': 61837,
#     'ts': datetime.datetime(2013, 9, 15, 19, 44, 32, 523844),
#     'uid': 'C3FEbf1UE7vMLkkQLc'}
# {   'AA': False,
#     'RA': True,
#     'RD': True,
#     'TC': False,
#     'TTLs': '2687.000000,219.000000',
#     'Z': 0,
#     'answers': 'googleapis.l.google.com,74.125.129.95',
#     'id.orig_h': '192.168.33.10',
#     'id.orig_p': 1081,
#     'id.resp_h': '4.2.2.3',
#     'id.resp_p': 53,
#     'proto': 'udp',
#     'qclass': 1,
#     'qclass_name': 'C_INTERNET',
#     'qtype': 1,
#     'qtype_name': 'A',
#     'query': 'ajax.googleapis.com',
#     'rcode': 0,
#     'rcode_name': 'NOERROR',
#     'rejected': False,
#     'trans_id': 19087,
#     'ts': datetime.datetime(2013, 9, 15, 19, 44, 32, 535704),
#     'uid': 'C3FEbf1UE7vMLkkQLc'}
# {   'AA': False,
#     'RA': True,
#     'RD': True,
#     'TC': False,
#     'TTLs': '221.000000,221.000000,221.000000',
#     'Z': 0,
#     'answers': 's0-2mdn-net.l.google.com,74.125.224.220,74.125.224.219',
#     'id.orig_h': '192.168.33.10',
#     'id.orig_p': 1081,
#     'id.resp_h': '4.2.2.3',
#     'id.resp_p': 53,
#     'proto': 'udp',
#     'qclass': 1,
#     'qclass_name': 'C_INTERNET',
#     'qtype': 1,
#     'qtype_name': 'A',
#     'query': 's0.2mdn.net',
#     'rcode': 0,
#     'rcode_name': 'NOERROR',
#     'rejected': False,
#     'trans_id': 62350,
#     'ts': datetime.datetime(2013, 9, 15, 19, 44, 32, 579891),
#     'uid': 'C3FEbf1UE7vMLkkQLc'}
# {   'AA': False,
#     'RA': True,
#     'RD': True,
#     'TC': False,
#     'TTLs': '1371.000000,111.000000,111.000000',
#     'Z': 0,
#     'answers': 'mscomajax.vo.msecnd.net,65.54.75.146,65.54.75.8',
#     'id.orig_h': '192.168.33.10',
#     'id.orig_p': 1081,
#     'id.resp_h': '4.2.2.3',
#     'id.resp_p': 53,
#     'proto': 'udp',
#     'qclass': 1,
#     'qclass_name': 'C_INTERNET',
#     'qtype': 1,
#     'qtype_name': 'A',
#     'query': 'ajax.aspnetcdn.com',
#     'rcode': 0,
#     'rcode_name': 'NOERROR',
#     'rejected': False,
#     'trans_id': 36745,
#     'ts': datetime.datetime(2013, 9, 15, 19, 44, 32, 962465),
#     'uid': 'C3FEbf1UE7vMLkkQLc'}
# {   'AA': False,
#     'RA': True,
#     'RD': True,
#     'TC': False,
#     'TTLs': '47.000000',
#     'Z': 0,
#     'answers': '74.125.224.79',
#     'id.orig_h': '192.168.33.10',
#     'id.orig_p': 1081,
#     'id.resp_h': '4.2.2.3',
#     'id.resp_p': 53,
#     'proto': 'udp',
#     'qclass': 1,
#     'qclass_name': 'C_INTERNET',
#     'qtype': 1,
#     'qtype_name': 'A',
#     'query': 'maps.gstatic.com',
#     'rcode': 0,
#     'rcode_name': 'NOERROR',
#     'rejected': False,
#     'trans_id': 64648,
#     'ts': datetime.datetime(2013, 9, 15, 19, 44, 33, 301834),
#     'uid': 'C3FEbf1UE7vMLkkQLc'}
# {   'AA': False,
#     'RA': True,
#     'RD': True,
#     'TC': False,
#     'TTLs': '29.000000',
#     'Z': 0,
#     'answers': '50.19.253.34',
#     'id.orig_h': '192.168.33.10',
#     'id.orig_p': 1081,
#     'id.resp_h': '4.2.2.3',
#     'id.resp_p': 53,
#     'proto': 'udp',
#     'qclass': 1,
#     'qclass_name': 'C_INTERNET',
#     'qtype': 1,
#     'qtype_name': 'A',
#     'query': 'assets.pinterest.com',
#     'rcode': 0,
#     'rcode_name': 'NOERROR',
#     'rejected': False,
#     'trans_id': 65162,
#     'ts': datetime.datetime(2013, 9, 15, 19, 44, 34, 901654),
#     'uid': 'C3FEbf1UE7vMLkkQLc'}
# {   'AA': False,
#     'RA': True,
#     'RD': True,
#     'TC': False,
#     'TTLs': '48690.000000,10762.000000,20.000000',
#     'Z': 0,
#     'answers': 'wildcard.uservoice.com.edgekey.net,e319.g.akamaiedge.net,23.73.225.107',
#     'id.orig_h': '192.168.33.10',
#     'id.orig_p': 1081,
#     'id.resp_h': '4.2.2.3',
#     'id.resp_p': 53,
#     'proto': 'udp',
#     'qclass': 1,
#     'qclass_name': 'C_INTERNET',
#     'qtype': 1,
#     'qtype_name': 'A',
#     'query': 'widget.uservoice.com',
#     'rcode': 0,
#     'rcode_name': 'NOERROR',
#     'rejected': False,
#     'trans_id': 32692,
#     'ts': datetime.datetime(2013, 9, 15, 19, 44, 35, 543926),
#     'uid': 'C3FEbf1UE7vMLkkQLc'}
# {   'AA': False,
#     'RA': True,
#     'RD': True,
#     'TC': False,
#     'TTLs': '60.000000',
#     'Z': 0,
#     'answers': '108.59.9.32',
#     'id.orig_h': '192.168.33.10',
#     'id.orig_p': 1081,
#     'id.resp_h': '4.2.2.3',
#     'id.resp_p': 53,
#     'proto': 'udp',
#     'qclass': 1,
#     'qclass_name': 'C_INTERNET',
#     'qtype': 1,
#     'qtype_name': 'A',
#     'query': 'hnhmrkw.myftp.biz',
#     'rcode': 0,
#     'rcode_name': 'NOERROR',
#     'rejected': False,
#     'trans_id': 44468,
#     'ts': datetime.datetime(2013, 9, 15, 19, 44, 36, 939748),
#     'uid': 'C3FEbf1UE7vMLkkQLc'}
# {   'AA': False,
#     'RA': True,
#     'RD': True,
#     'TC': False,
#     'TTLs': '300.000000',
#     'Z': 0,
#     'answers': '50.28.49.153',
#     'id.orig_h': '192.168.33.10',
#     'id.orig_p': 1081,
#     'id.resp_h': '4.2.2.3',
#     'id.resp_p': 53,
#     'proto': 'udp',
#     'qclass': 1,
#     'qclass_name': 'C_INTERNET',
#     'qtype': 1,
#     'qtype_name': 'A',
#     'query': 'cdn.tapstream.com',
#     'rcode': 0,
#     'rcode_name': 'NOERROR',
#     'rejected': False,
#     'trans_id': 10166,
#     'ts': datetime.datetime(2013, 9, 15, 19, 44, 37, 132249),
#     'uid': 'C3FEbf1UE7vMLkkQLc'}
# {   'AA': False,
#     'RA': True,
#     'RD': True,
#     'TC': False,
#     'TTLs': '8836.000000,296.000000,4969.000000,16.000000,16.000000',
#     'Z': 0,
#     'answers': 'fpdownload2.wip4.adobe.com,fpdownload.macromedia.com.edgesuite.net,a1293.d.akamai.net,96.17.148.33,96.17.148.41',
#     'id.orig_h': '192.168.33.10',
#     'id.orig_p': 1081,
#     'id.resp_h': '4.2.2.3',
#     'id.resp_p': 53,
#     'proto': 'udp',
#     'qclass': 1,
#     'qclass_name': 'C_INTERNET',
#     'qtype': 1,
#     'qtype_name': 'A',
#     'query': 'fpdownload2.macromedia.com',
#     'rcode': 0,
#     'rcode_name': 'NOERROR',
#     'rejected': False,
#     'trans_id': 26033,
#     'ts': datetime.datetime(2013, 9, 15, 19, 44, 37, 455342),
#     'uid': 'C3FEbf1UE7vMLkkQLc'}
# {   'AA': False,
#     'RA': True,
#     'RD': True,
#     'TC': False,
#     'TTLs': '300.000000,300.000000',
#     'Z': 0,
#     'answers': '50.28.54.4,50.28.104.12',
#     'id.orig_h': '192.168.33.10',
#     'id.orig_p': 1081,
#     'id.resp_h': '4.2.2.3',
#     'id.resp_p': 53,
#     'proto': 'udp',
#     'qclass': 1,
#     'qclass_name': 'C_INTERNET',
#     'qtype': 1,
#     'qtype_name': 'A',
#     'query': 'api.taps.io',
#     'rcode': 0,
#     'rcode_name': 'NOERROR',
#     'rejected': False,
#     'trans_id': 17328,
#     'ts': datetime.datetime(2013, 9, 15, 19, 44, 37, 473509),
#     'uid': 'C3FEbf1UE7vMLkkQLc'}
# {   'AA': False,
#     'RA': True,
#     'RD': True,
#     'TC': False,
#     'TTLs': '2185.000000',
#     'Z': 0,
#     'answers': '108.168.255.244',
#     'id.orig_h': '192.168.33.10',
#     'id.orig_p': 1134,
#     'id.resp_h': '8.8.8.8',
#     'id.resp_p': 53,
#     'proto': 'udp',
#     'qclass': 1,
#     'qclass_name': 'C_INTERNET',
#     'qtype': 1,
#     'qtype_name': 'A',
#     'query': 'j.maxmind.com',
#     'rcode': 0,
#     'rcode_name': 'NOERROR',
#     'rejected': False,
#     'trans_id': 13107,
#     'ts': datetime.datetime(2013, 9, 15, 19, 44, 50, 384356),
#     'uid': 'CYZwkh4N764XThV8n5'}
# {   'AA': False,
#     'RA': True,
#     'RD': True,
#     'TC': False,
#     'TTLs': '86400.000000',
#     'Z': 0,
#     'answers': '74.86.20.50',
#     'id.orig_h': '192.168.33.10',
#     'id.orig_p': 1081,
#     'id.resp_h': '4.2.2.3',
#     'id.resp_p': 53,
#     'proto': 'udp',
#     'qclass': 1,
#     'qclass_name': 'C_INTERNET',
#     'qtype': 1,
#     'qtype_name': 'A',
#     'query': 'twinkcam.net',
#     'rcode': 0,
#     'rcode_name': 'NOERROR',
#     'rejected': False,
#     'trans_id': 27824,
#     'ts': datetime.datetime(2013, 9, 15, 19, 44, 55, 365238),
#     'uid': 'CPY8QmQNINcEhF1e'}
# {   'AA': False,
#     'RA': True,
#     'RD': True,
#     'TC': False,
#     'TTLs': '300.000000',
#     'Z': 0,
#     'answers': '216.17.105.36',
#     'id.orig_h': '192.168.33.10',
#     'id.orig_p': 1081,
#     'id.resp_h': '4.2.2.3',
#     'id.resp_p': 53,
#     'proto': 'udp',
#     'qclass': 1,
#     'qclass_name': 'C_INTERNET',
#     'qtype': 1,
#     'qtype_name': 'A',
#     'query': 'cinnamyn.com',
#     'rcode': 0,
#     'rcode_name': 'NOERROR',
#     'rejected': False,
#     'trans_id': 44976,
#     'ts': datetime.datetime(2013, 9, 15, 19, 44, 55, 990539),
#     'uid': 'CPY8QmQNINcEhF1e'}
# {   'AA': False,
#     'RA': False,
#     'RD': False,
#     'TC': False,
#     'TTLs': '-',
#     'Z': 0,
#     'answers': '-',
#     'id.orig_h': '192.168.33.10',
#     'id.orig_p': 1142,
#     'id.resp_h': '194.165.17.4',
#     'id.resp_p': 53,
#     'proto': 'udp',
#     'qclass': 0,
#     'qclass_name': '-',
#     'qtype': 0,
#     'qtype_name': '-',
#     'query': '-',
#     'rcode': 0,
#     'rcode_name': '-',
#     'rejected': False,
#     'trans_id': 15387,
#     'ts': datetime.datetime(2013, 9, 15, 19, 44, 50, 827882),
#     'uid': 'CqJDTf39f4HiGL7MP8'}
# {   'AA': False,
#     'RA': False,
#     'RD': False,
#     'TC': False,
#     'TTLs': '-',
#     'Z': 0,
#     'answers': '-',
#     'id.orig_h': '192.168.33.10',
#     'id.orig_p': 1143,
#     'id.resp_h': '194.165.17.4',
#     'id.resp_p': 53,
#     'proto': 'udp',
#     'qclass': 0,
#     'qclass_name': '-',
#     'qtype': 0,
#     'qtype_name': '-',
#     'query': '-',
#     'rcode': 0,
#     'rcode_name': '-',
#     'rejected': False,
#     'trans_id': 15387,
#     'ts': datetime.datetime(2013, 9, 15, 19, 44, 50, 829302),
#     'uid': 'CnEqamUfi1nKgsIyl'}
# {   'AA': False,
#     'RA': False,
#     'RD': False,
#     'TC': False,
#     'TTLs': '-',
#     'Z': 0,
#     'answers': '-',
#     'id.orig_h': '192.168.33.10',
#     'id.orig_p': 1147,
#     'id.resp_h': '194.165.17.4',
#     'id.resp_p': 53,
#     'proto': 'udp',
#     'qclass': 0,
#     'qclass_name': '-',
#     'qtype': 0,
#     'qtype_name': '-',
#     'query': '-',
#     'rcode': 0,
#     'rcode_name': '-',
#     'rejected': False,
#     'trans_id': 15387,
#     'ts': datetime.datetime(2013, 9, 15, 19, 44, 51, 26231),
#     'uid': 'CAIPUU1mXDNkDAr7Dc'}
# {   'AA': False,
#     'RA': True,
#     'RD': True,
#     'TC': False,
#     'TTLs': '300.000000,300.000000,300.000000,300.000000,300.000000',
#     'Z': 0,
#     'answers': '74.125.239.148,74.125.239.147,74.125.239.145,74.125.239.146,74.125.239.144',
#     'id.orig_h': '192.168.33.10',
#     'id.orig_p': 1163,
#     'id.resp_h': '8.8.8.8',
#     'id.resp_p': 53,
#     'proto': 'udp',
#     'qclass': 1,
#     'qclass_name': 'C_INTERNET',
#     'qtype': 1,
#     'qtype_name': 'A',
#     'query': 'www.google.com',
#     'rcode': 0,
#     'rcode_name': 'NOERROR',
#     'rejected': False,
#     'trans_id': 13107,
#     'ts': datetime.datetime(2013, 9, 15, 19, 45, 1, 477332),
#     'uid': 'CEHVfa1kqFmL48R1rd'}
# {   'AA': False,
#     'RA': True,
#     'RD': True,
#     'TC': False,
#     'TTLs': '86400.000000',
#     'Z': 0,
#     'answers': '74.86.20.50',
#     'id.orig_h': '192.168.33.10',
#     'id.orig_p': 1081,
#     'id.resp_h': '4.2.2.3',
#     'id.resp_p': 53,
#     'proto': 'udp',
#     'qclass': 1,
#     'qclass_name': 'C_INTERNET',
#     'qtype': 1,
#     'qtype_name': 'A',
#     'query': 'saggerboy.com',
#     'rcode': 0,
#     'rcode_name': 'NOERROR',
#     'rejected': False,
#     'trans_id': 9906,
#     'ts': datetime.datetime(2013, 9, 15, 19, 45, 55, 898067),
#     'uid': 'ChC22P2JDl7rh3qOO'}
# {   'AA': False,
#     'RA': True,
#     'RD': True,
#     'TC': False,
#     'TTLs': '1993.000000',
#     'Z': 0,
#     'answers': '108.168.255.244',
#     'id.orig_h': '192.168.33.10',
#     'id.orig_p': 1166,
#     'id.resp_h': '8.8.8.8',
#     'id.resp_p': 53,
#     'proto': 'udp',
#     'qclass': 1,
#     'qclass_name': 'C_INTERNET',
#     'qtype': 1,
#     'qtype_name': 'A',
#     'query': 'j.maxmind.com',
#     'rcode': 0,
#     'rcode_name': 'NOERROR',
#     'rejected': False,
#     'trans_id': 13107,
#     'ts': datetime.datetime(2013, 9, 15, 19, 48, 2, 397021),
#     'uid': 'CiXWly2e5NcVjsKa82'}
# {   'AA': False,
#     'RA': True,
#     'RD': True,
#     'TC': False,
#     'TTLs': '1993.000000',
#     'Z': 0,
#     'answers': '108.168.255.244',
#     'id.orig_h': '192.168.33.10',
#     'id.orig_p': 1166,
#     'id.resp_h': '8.8.8.8',
#     'id.resp_p': 53,
#     'proto': 'udp',
#     'qclass': 1,
#     'qclass_name': 'C_INTERNET',
#     'qtype': 1,
#     'qtype_name': 'A',
#     'query': 'superlongcrazydnsqueryforoutlierdetectionj.maxmind.com',
#     'rcode': 0,
#     'rcode_name': 'NOERROR',
#     'rejected': False,
#     'trans_id': 13107,
#     'ts': datetime.datetime(2013, 9, 15, 19, 48, 2, 497021),
#     'uid': 'CiXWly2e5NcVjsKa82'}
# {   'AA': False,
#     'RA': True,
#     'RD': True,
#     'TC': False,
#     'TTLs': '1993.000000',
#     'Z': 0,
#     'answers': '108.168.255.244',
#     'id.orig_h': '192.168.33.10',
#     'id.orig_p': 1166,
#     'id.resp_h': '8.8.8.8',
#     'id.resp_p': 53,
#     'proto': 'udp',
#     'qclass': 1,
#     'qclass_name': 'C_INTERNET',
#     'qtype': 1,
#     'qtype_name': 'A',
#     'query': 'xyzqsuperlongcrazydnsqueryforoutlierdetectionj.maxmind.com',
#     'rcode': 0,
#     'rcode_name': 'NOERROR',
#     'rejected': False,
#     'trans_id': 13107,
#     'ts': datetime.datetime(2013, 9, 15, 19, 48, 2, 597021),
#     'uid': 'CiXWly2e5NcVjsKa82'}
# {   'AA': False,
#     'RA': True,
#     'RD': True,
#     'TC': False,
#     'TTLs': '1993.000000',
#     'Z': 0,
#     'answers': '108.168.255.244',
#     'id.orig_h': '192.168.33.10',
#     'id.orig_p': 1166,
#     'id.resp_h': '8.8.8.8',
#     'id.resp_p': 53,
#     'proto': 'udp',
#     'qclass': 1,
#     'qclass_name': 'C_INTERNET',
#     'qtype': 1,
#     'qtype_name': 'A',
#     'query': 'abcsuperlongcrazydnsqueryforoutlierdetectionj.maxmind.com',
#     'rcode': 0,
#     'rcode_name': 'NOERROR',
#     'rejected': False,
#     'trans_id': 13107,
#     'ts': datetime.datetime(2013, 9, 15, 19, 48, 2, 697021),
#     'uid': 'CiXWly2e5NcVjsKa82'}
# {   'AA': False,
#     'RA': True,
#     'RD': True,
#     'TC': False,
#     'TTLs': '1993.000000',
#     'Z': 1,
#     'answers': '108.168.255.244',
#     'id.orig_h': '192.168.33.10',
#     'id.orig_p': 1166,
#     'id.resp_h': '8.8.8.8',
#     'id.resp_p': 53,
#     'proto': 'udp',
#     'qclass': 1,
#     'qclass_name': 'C_INTERNET',
#     'qtype': 1,
#     'qtype_name': 'A',
#     'query': 'j.maxmind.com',
#     'rcode': 0,
#     'rcode_name': 'NOERROR',
#     'rejected': False,
#     'trans_id': 13107,
#     'ts': datetime.datetime(2013, 9, 15, 19, 48, 2, 897021),
#     'uid': 'CiXWly2e5NcVjsKa82'}
# {   'AA': False,
#     'RA': True,
#     'RD': True,
#     'TC': False,
#     'TTLs': '1993.000000',
#     'Z': 1,
#     'answers': '108.168.255.244',
#     'id.orig_h': '192.168.33.10',
#     'id.orig_p': 1166,
#     'id.resp_h': '8.8.8.8',
#     'id.resp_p': 53,
#     'proto': 'udp',
#     'qclass': 1,
#     'qclass_name': 'C_INTERNET',
#     'qtype': 1,
#     'qtype_name': 'A',
#     'query': 'j.maxmind.com',
#     'rcode': 0,
#     'rcode_name': 'NOERROR',
#     'rejected': False,
#     'trans_id': 13107,
#     'ts': datetime.datetime(2013, 9, 15, 19, 48, 4, 897021),
#     'uid': 'CiXWly2e5NcVjsKa82'}
# {   'AA': False,
#     'RA': True,
#     'RD': True,
#     'TC': False,
#     'TTLs': '1993.000000',
#     'Z': 1,
#     'answers': '108.168.255.244',
#     'id.orig_h': '192.168.33.10',
#     'id.orig_p': 1166,
#     'id.resp_h': '8.8.8.8',
#     'id.resp_p': 53,
#     'proto': 'udp',
#     'qclass': 1,
#     'qclass_name': 'C_INTERNET',
#     'qtype': 1,
#     'qtype_name': 'A',
#     'query': 'j.maxmind.com',
#     'rcode': 0,
#     'rcode_name': 'NOERROR',
#     'rejected': False,
#     'trans_id': 13107,
#     'ts': datetime.datetime(2013, 9, 15, 19, 48, 4, 997021),
#     'uid': 'CiXWly2e5NcVjsKa82'}
# {   'AA': False,
#     'RA': True,
#     'RD': True,
#     'TC': False,
#     'TTLs': '1993.000000',
#     'Z': 0,
#     'answers': '108.168.255.244',
#     'id.orig_h': '192.168.33.10',
#     'id.orig_p': 1166,
#     'id.resp_h': '8.8.8.8',
#     'id.resp_p': 53,
#     'proto': 'tcp',
#     'qclass': 1,
#     'qclass_name': 'C_INTERNET',
#     'qtype': 1,
#     'qtype_name': 'A',
#     'query': 'j.maxmind.com',
#     'rcode': 0,
#     'rcode_name': 'NOERROR',
#     'rejected': False,
#     'trans_id': 13107,
#     'ts': datetime.datetime(2013, 9, 15, 19, 48, 5, 897021),
#     'uid': 'CiXWly2e5NcVjsKa82'}
# {   'AA': False,
#     'RA': True,
#     'RD': True,
#     'TC': False,
#     'TTLs': '1993.000000',
#     'Z': 0,
#     'answers': '108.168.255.244',
#     'id.orig_h': '192.168.33.10',
#     'id.orig_p': 1166,
#     'id.resp_h': '8.8.8.8',
#     'id.resp_p': 53,
#     'proto': 'tcp',
#     'qclass': 1,
#     'qclass_name': 'C_INTERNET',
#     'qtype': 1,
#     'qtype_name': 'A',
#     'query': 'j.maxmind.com',
#     'rcode': 0,
#     'rcode_name': 'NOERROR',
#     'rejected': False,
#     'trans_id': 13107,
#     'ts': datetime.datetime(2013, 9, 15, 19, 48, 6, 897021),
#     'uid': 'CiXWly2e5NcVjsKa82'}
# {   'AA': False,
#     'RA': True,
#     'RD': True,
#     'TC': False,
#     'TTLs': '1993.000000',
#     'Z': 0,
#     'answers': '108.168.255.244',
#     'id.orig_h': '192.168.33.10',
#     'id.orig_p': 1166,
#     'id.resp_h': '8.8.8.8',
#     'id.resp_p': 53,
#     'proto': 'tcp',
#     'qclass': 1,
#     'qclass_name': 'C_INTERNET',
#     'qtype': 1,
#     'qtype_name': 'A',
#     'query': 'j.maxmind.com',
#     'rcode': 0,
#     'rcode_name': 'NOERROR',
#     'rejected': False,
#     'trans_id': 13107,
#     'ts': datetime.datetime(2013, 9, 15, 19, 48, 7, 897021),
#     'uid': 'CiXWly2e5NcVjsKa82'}
